# %%
#1. Importing Libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.optimizers import Adam

# %%
#2. Loading the Dataset
df = pd.read_csv('data.csv', parse_dates=['Date'], index_col='Date')
print(df.head())
# Out:
#             Temperature
# Date
# 2010-01-01    27.483571
# 2010-01-02    24.308678
# 2010-01-03    28.238443
# 2010-01-04    32.615149
# 2010-01-05    23.829233

# %%
#3. Preprocessing the Data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df.values)

# %%
#4. Preparing Data for GRU
def create_dataset(data, time_step=1):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)


time_step = 100
X, y = create_dataset(scaled_data, time_step)
X = X.reshape(X.shape[0], X.shape[1], 1)

# %%
#5. Building the GRU Model
model = Sequential()
model.add(GRU(units=50, return_sequences=True, input_shape=(X.shape[1], 1)))
model.add(GRU(units=50))
model.add(Dense(units=1))
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
# Out:
# c:\Users\paras\OneDrive\Desktop\dsa_in_python\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.fit(X,y, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - loss: 0.0207
# Epoch 2/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - loss: 0.0183
# Epoch 3/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - loss: 0.0181
# Epoch 4/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - loss: 0.0180
# Epoch 5/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - loss: 0.0177
# Epoch 6/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - loss: 0.0177
# Epoch 7/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - loss: 0.0178
# Epoch 8/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - loss: 0.0179
# Epoch 9/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - loss: 0.0176
# Epoch 10/10
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - loss: 0.0176

# %%
input_sequence = scaled_data[-time_step:].reshape(1, time_step, 1)
predicted_values = model.predict(input_sequence)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step

# %%
predicted_values = scaler.inverse_transform(predicted_values)
print(f"The predicted temperature for the next day is: {predicted_values[0][0]:.2f}C")
# Out:
# The predicted temperature for the next day is: 24.91C
