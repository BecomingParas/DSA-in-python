# %% [markdown]
# 1. fixed sized array

# %%
arr = [0] * 5


print(arr)
# Out:
# [0, 0, 0, 0, 0]

# %% [markdown]
# 2. Dynamic array

# %%
arr = []
print(arr)
# Out:
# []

# %% [markdown]
# Creating list in the python

# %% [markdown]
# 1. using square bracket

# %%
a = [1,2,3,4] #list of the integrer
b= ['apple', 'ball', 'cat'] # list of the string
c= [1,'hello', '3.14',True] # list of the mixed

print(a)
print(b)
print(c)
# Out:
# [1, 2, 3, 4]
# ['apple', 'ball', 'cat']
# [1, 'hello', '3.14', True]

# %% [markdown]
# 2. using a list construtuor

# %%
 a = list((1,2,'banana',4.5))
 print(a)
 b = list("abc")
 print(b)
# Out:
# [1, 2, 'banana', 4.5]
# ['a', 'b', 'c']

# %% [markdown]
# 3. creating a list with repeating element

# %%
a = [2] * 4
print(a)
# Out:
# [2, 2, 2, 2]
