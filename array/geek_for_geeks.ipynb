# %% [markdown]
# 1. fixed sized array

# %%
arr = [0] * 5


print(arr)
# Out:
# [0, 0, 0, 0, 0]

# %% [markdown]
# 2. Dynamic array

# %%
arr = []
print(arr)
# Out:
# []

# %% [markdown]
# Creating list in the python

# %% [markdown]
# 1. using square bracket

# %%
a = [1,2,3,4] #list of the integrer
b= ['apple', 'ball', 'cat'] # list of the string
c= [1,'hello', '3.14',True] # list of the mixed

print(a)
print(b)
print(c)
# Out:
# [1, 2, 3, 4]
# ['apple', 'ball', 'cat']
# [1, 'hello', '3.14', True]

# %% [markdown]
# 2. using a list construtuor

# %%
 a = list((1,2,'banana',4.5))
 print(a)
 b = list("abc")
 print(b)
# Out:
# [1, 2, 'banana', 4.5]
# ['a', 'b', 'c']

# %% [markdown]
# 3. creating a list with repeating element

# %%
a = [2] * 4
print(a)
# Out:
# [2, 2, 2, 2]

# %% [markdown]
# ### Accessing elements in the lists

# %%
a = [10,20,30,40,50]
print(a[0])
print(a[-1])
print(a[1:4])
# Out:
# 10
# 50
# [20, 30, 40]

# %% [markdown]
# ### Adding element to the lists

# %%
a = []

a.append(10)
print("After append(10):",a)

a.insert(0,5)
print("After insert(0,5):",a)

a.extend([15,20,25])
print("After extend ([15,20,25]):",a)

a.clear()
print("After clear():",a)
# Out:
# After append(10): [10]
# After insert(0,5): [5, 10]
# After extend ([15,20,25]): [5, 10, 15, 20, 25]
# After clear(): []

# %% [markdown]
# ### Updating element in List

# %%
a = [10,20,30,40,50]
a[1] = 1000
print(a)
# Out:
# [10, 1000, 30, 40, 50]

# %% [markdown]
# Removing element in List

# %%
a = [10,20,30,40,50,30]


a.remove(30) # remove the first occurance of the list only remove first element
print("After remove(30)",a)

popped_val = a.pop(1) # Removes the element at a specific index or the last element if no index is specified

print("Popped element:", popped_val)
print("After pop(1):", a) 

del a[0]
print('print after del[0]:',a)
# Out:
# After remove(30) [10, 20, 40, 50, 30]
# Popped element: 20
# After pop(1): [10, 40, 50, 30]
# print after del[0]: [40, 50, 30]

# %% [markdown]
# Iterating Over lists

# %%
a = ['apple', 'banana','cherry']

for item in a:
    print(item)
# Out:
# apple
# banana
# cherry

# %%
matrix = [ [1, 2, 3],
           [4, 5, 6],
           [7, 8, 9] ]
print(matrix[1][2])
# Out:
# 6

# %% [markdown]
# List comprehension

# %%
squares = [x**2 for x in range(1, 6)]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ### Alternate element of array

# %% [markdown]
# Input: arr[] = [10, 20, 30, 40, 50]
# Output: 10 30 50
# Explanation: Print the first element (10), skip the second element (20), print the third element (30), skip the fourth element(40) and print the fifth element(50).
#
# Input: arr[] = [-5, 1, 4, 2, 12]
# Output: -5 4 12
#
# The idea is to start iterating from index 0, print the element at that index, and then increment the index by 2 to move to the next alternate element. Keep on printing the elements till we reach the end of the array.

# %% [markdown]
# 1. Iterative approach

# %%
def get_alternates(arr):
    res = []
    for i in range(0, len(arr), 2):
        res.append(arr[i])
    return res

if __name__ == "__main__":
    arr = [10,20,30,40,50]
    res = get_alternates(arr)
    print(" ".join(map(str, res)))

# time complexity = O(n)
# Out:
# 10 30 50

# %% [markdown]
# 2. Recursive approach

# %%
def get_alternates_rec(arr, idx, res):
    if idx < len(arr):
        res.append(arr[idx])
        get_alternates_rec(arr,idx + 2, res)
